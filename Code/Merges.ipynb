# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tech = pd.read_csv('/Users/annamezhlauk/Desktop/ECO225Project/Data/Tech_salaries.csv')
objects = pd.read_csv('/Users/annamezhlauk/Desktop/ECO225Project/Data/Startups/objects.csv', low_memory = False)

# %%
objects.rename(columns = {"normalized_name": "employer_name"}, inplace = True)
print(objects.dtypes)
objects.head(25)
# Out:
# id                      object
# entity_type             object
# entity_id                int64
# parent_id               object
# name                    object
# employer_name           object
# permalink               object
# category_code           object
# status                  object
# founded_at              object
# closed_at               object
# domain                  object
# homepage_url            object
# twitter_username        object
# logo_url                object
# logo_width               int64
# logo_height              int64
# short_description       object
# description             object
# overview                object
# tag_list                object
# country_code            object
# state_code              object
# city                    object
# region                  object
# first_investment_at     object
# last_investment_at      object
# investment_rounds        int64
# invested_companies       int64
# first_funding_at        object
# last_funding_at         object
# funding_rounds           int64
# funding_total_usd      float64
# first_milestone_at      object
# last_milestone_at       object
# milestones               int64
# relationships            int64
# created_by              object
# created_at              object
# updated_at              object
# dtype: object
#           id entity_type  entity_id parent_id                           name  \
# 0        c:1     Company          1       NaN                       Wetpaint
# 1       c:10     Company         10       NaN                        Flektor
# 2      c:100     Company        100       NaN                          There
# 3    c:10000     Company      10000       NaN                        MYWEBBO
# 4    c:10001     Company      10001       NaN             THE Movie Streamer
# 5    c:10002     Company      10002       NaN                 Synergie Media
# 6    c:10003     Company      10003       NaN         Green Basti Ecosystems
# 7   c:100042     Company     100042       NaN                       HostNine
# 8    c:10005     Company      10005       NaN              Thomas Publishing
# 9   c:100062     Company     100062       NaN  Vetter Idea Management System
# 10  c:100068     Company     100068       NaN                     ChatRandom
# 11   c:10008     Company      10008       NaN               ScapadasAmorosas
# 12   c:10009     Company      10009       NaN                dimension5 labs
# 13    c:1001     Company       1001       NaN                     FriendFeed
# 14   c:10010     Company      10010       NaN                      Whooligan
# 15   c:10011     Company      10011       NaN           PoetryVisualized.com
# 16   c:10012     Company      10012       NaN                moviestring.com
# 17   c:10013     Company      10013       NaN                      The Adory
# 18   c:10014     Company      10014       NaN                        Mobclix
# 19   c:10015     Company      10015       NaN                         Fitbit
# 20  c:100155     Company     100155       NaN                           MTPV
# 21   c:10016     Company      10016       NaN         Camcorder-batteries.us
# 22  c:100174     Company     100174       NaN                        Paydirt
# 23  c:100178     Company     100178       NaN                        Wreally
# 24   c:10018     Company      10018       NaN                     Demandbase
#
#                     employer_name                               permalink  \
# 0                        wetpaint                       /company/wetpaint
# 1                         flektor                        /company/flektor
# 2                           there                          /company/there
# 3                         mywebbo                        /company/mywebbo
# 4              the movie streamer             /company/the-movie-streamer
# 5                  synergie media                 /company/synergie-media
# 6          green basti ecosystems         /company/green-basti-ecosystems
# 7                        hostnine                       /company/hostnine
# 8               thomas publishing              /company/thomas-publishing
# 9   vetter idea management system  /company/vetter-idea-management-system
# 10                     chatrandom                     /company/chatrandom
# 11               scapadasamorosas               /company/scapadasamorosas
# 12                dimension5 labs                /company/dimension5-labs
# 13                     friendfeed                     /company/friendfeed
# 14                      whooligan                      /company/whooligan
# 15               poetryvisualized           /company/poetryvisualized-com
# 16                    moviestring                /company/moviestring-com
# 17                      the adory                      /company/the-adory
# 18                        mobclix                        /company/mobclix
# 19                         fitbit                         /company/fitbit
# 20                           mtpv                           /company/mtpv
# 21         camcorder batteries us         /company/camcorder-batteries-us
# 22                        paydirt                        /company/paydirt
# 23                        wreally                        /company/wreally
# 24                     demandbase                     /company/demandbase
#
#       category_code     status  founded_at  ... last_funding_at  \
# 0               web  operating  2005-10-17  ...      2008-05-19
# 1       games_video   acquired         NaN  ...             NaN
# 2       games_video   acquired         NaN  ...             NaN
# 3   network_hosting  operating  2008-07-26  ...             NaN
# 4       games_video  operating  2008-07-26  ...             NaN
# 5       advertising  operating  2007-06-27  ...             NaN
# 6         cleantech  operating  2008-08-20  ...             NaN
# 7               NaN  operating         NaN  ...             NaN
# 8       advertising  operating         NaN  ...             NaN
# 9        enterprise  operating  2011-08-01  ...             NaN
# 10      games_video  operating  2011-02-01  ...             NaN
# 11            other  operating  2007-03-01  ...             NaN
# 12      advertising  operating  2008-08-01  ...             NaN
# 13              web   acquired  2007-10-01  ...      2008-02-26
# 14      games_video  operating  2007-12-01  ...             NaN
# 15      games_video  operating  2008-01-01  ...             NaN
# 16      games_video     closed  2008-08-22  ...             NaN
# 17       consulting  operating  2008-01-01  ...             NaN
# 18           mobile   acquired  2008-03-01  ...      2008-09-01
# 19           health  operating  2007-10-01  ...      2013-08-13
# 20        cleantech  operating  2003-01-01  ...      2012-01-26
# 21            other  operating         NaN  ...             NaN
# 22         software  operating  2011-01-25  ...             NaN
# 23              web  operating  2009-03-01  ...             NaN
# 24        analytics  operating  2006-01-01  ...      2013-03-28
#
#    funding_rounds funding_total_usd first_milestone_at last_milestone_at  \
# 0               3        39750000.0         2010-09-05        2013-09-18
# 1               0               0.0                NaN               NaN
# 2               0               0.0         2003-02-01        2011-09-23
# 3               0               0.0                NaN               NaN
# 4               0               0.0                NaN               NaN
# 5               0               0.0                NaN               NaN
# 6               0               0.0                NaN               NaN
# 7               0               0.0         2011-06-20        2011-06-20
# 8               0               0.0         1999-06-01        1999-06-01
# 9               0               0.0         2011-08-01        2011-08-01
# 10              0               0.0         2012-04-09        2012-04-09
# 11              0               0.0                NaN               NaN
# 12              0               0.0         2008-08-22        2008-08-22
# 13              1         5000000.0         2008-05-01        2012-09-13
# 14              0               0.0                NaN               NaN
# 15              0               0.0         2008-01-01        2008-01-01
# 16              0               0.0                NaN               NaN
# 17              0               0.0                NaN               NaN
# 18              1               0.0         1995-03-01        2012-09-18
# 19              5        68069200.0                NaN               NaN
# 20              3        10125293.0         2010-01-01        2010-01-01
# 21              0               0.0                NaN               NaN
# 22              0               0.0         2011-01-01        2011-01-01
# 23              0               0.0                NaN               NaN
# 24              3        33000000.0         2010-05-18        2013-03-01
#
#     milestones  relationships        created_by           created_at  \
# 0            5             17  initial-importer  2007-05-25 06:51:27
# 1            0              6  initial-importer  2007-05-31 21:11:51
# 2            4             12  initial-importer  2007-08-06 23:52:45
# 3            0              0               NaN  2008-08-24 16:51:57
# 4            0              0               NaN  2008-08-24 17:10:34
# 5            0              2               NaN  2008-08-24 17:39:10
# 6            0              0               NaN  2008-08-24 19:49:25
# 7            1              1               NaN  2011-09-07 00:53:17
# 8            1              2               NaN  2008-08-24 20:21:21
# 9            1              2          dmurtagh  2011-09-07 01:04:56
# 10           1              0               NaN  2011-09-07 01:09:59
# 11           0              0               NaN  2008-08-24 21:48:16
# 12           1              2               NaN  2008-08-24 21:54:55
# 13           3             14  initial-importer  2007-10-01 10:17:13
# 14           0              1               NaN  2008-08-24 22:10:04
# 15           1              3               NaN  2008-08-24 22:21:46
# 16           0              1               NaN  2008-08-24 23:07:26
# 17           0              2               NaN  2008-08-24 23:23:00
# 18           4              9               NaN  2008-08-25 01:32:43
# 19           0             14               NaN  2008-08-25 02:16:54
# 20           1              6              arun  2011-09-07 02:01:00
# 21           0              0               NaN  2008-08-25 02:17:08
# 22           1              2               NaN  2011-09-07 02:12:18
# 23           0              2        jasonbosco  2011-09-07 02:17:14
# 24           3             19             jason  2008-08-25 03:35:42
#
#              updated_at
# 0   2013-04-13 03:29:00
# 1   2008-05-23 23:23:14
# 2   2013-11-04 02:09:48
# 3   2008-09-06 14:19:18
# 4   2008-09-06 14:19:18
# 5   2008-09-06 14:19:19
# 6   2010-04-22 23:48:20
# 7   2011-12-20 09:09:53
# 8   2009-11-19 17:21:00
# 9   2011-09-24 13:13:18
# 10  2011-09-12 04:14:57
# 11  2013-04-02 12:36:50
# 12  2008-12-21 17:21:53
# 13  2013-03-13 21:44:15
# 14  2013-06-28 20:51:46
# 15  2009-04-03 20:32:21
# 16  2010-10-01 00:12:22
# 17  2009-04-03 18:00:41
# 18  2012-09-22 03:36:21
# 19  2013-12-04 09:52:42
# 20  2013-04-10 04:35:04
# 21  2009-03-14 14:41:42
# 22  2012-03-03 08:14:35
# 23  2011-09-24 13:13:32
# 24  2013-10-23 11:32:49
#
# [25 rows x 40 columns]

# %%
pre = tech.groupby("employer_name")

# %%
pre.head()

# %%
objects.describe()
# Out:
#            entity_id     logo_width    logo_height  investment_rounds  \
# count  462651.000000  462651.000000  462651.000000      462651.000000
# mean   132915.761775     189.159799     130.488664           0.173939
# std     88768.946816     432.403482     337.191612           3.637983
# min         1.000000       0.000000       0.000000           0.000000
# 25%     45249.500000       0.000000       0.000000           0.000000
# 50%    143072.000000       0.000000       0.000000           0.000000
# 75%    213868.500000     216.000000     139.000000           0.000000
# max    286215.000000   18200.000000    9600.000000         529.000000
#
#        invested_companies  funding_rounds  funding_total_usd     milestones  \
# count       462651.000000   462651.000000       4.626510e+05  462651.000000
# mean             0.138132        0.113749       8.926722e+05       0.265196
# std              2.549245        0.524229       1.700120e+07       0.568577
# min              0.000000        0.000000       0.000000e+00       0.000000
# 25%              0.000000        0.000000       0.000000e+00       0.000000
# 50%              0.000000        0.000000       0.000000e+00       0.000000
# 75%              0.000000        0.000000       0.000000e+00       0.000000
# max            459.000000       15.000000       5.700000e+09       9.000000
#
#        relationships
# count  462651.000000
# mean        1.794305
# std         5.456711
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max      1189.000000

# %%
combo = tech.merge(objects, how="left", on = "employer_name")

# %%
combo.head()
# Out:
#    index  salary_id       employer_name      location_name location_state  \
# 0      0          1              opower  san francisco, ca             CA
# 1      1          3             walmart    bentonville, ar             AR
# 2      2          4  vertical knowledge      cleveland, oh             OH
# 3      3          6              netapp            waltham            NaN
# 4      4         12               apple          cupertino            NaN
#
#   location_country  location_latitude  location_longitude          job_title  \
# 0               US              37.77             -122.41   systems engineer
# 1               US              36.36              -94.20   senior developer
# 2               US              41.47              -81.67  software engineer
# 3              NaN                NaN                 NaN                mts
# 4              NaN                NaN                 NaN  software engineer
#
#   job_title_category  ... last_funding_at  funding_rounds  funding_total_usd  \
# 0        Engineering  ...      2010-11-29             3.0         65700000.0
# 1           Software  ...             NaN             0.0                0.0
# 2           Software  ...             NaN             NaN                NaN
# 3              Other  ...             NaN             0.0                0.0
# 4           Software  ...             NaN             0.0                0.0
#
#    first_milestone_at  last_milestone_at  milestones relationships  \
# 0          2012-02-15         2013-09-01         3.0          27.0
# 1          2012-02-19         2013-11-29         3.0          85.0
# 2                 NaN                NaN         NaN           NaN
# 3          2011-05-09         2012-10-15         3.0          46.0
# 4          2013-03-05         2013-12-11         4.0         469.0
#
#          created_by           created_at           updated_at
# 0            svetla  2009-08-13 14:06:00  2013-07-25 20:10:17
# 1               NaN  2009-08-06 18:53:35  2013-10-30 21:48:04
# 2               NaN                  NaN                  NaN
# 3  initial-importer  2008-01-04 07:41:24  2009-09-24 06:26:32
# 4  initial-importer  2007-12-22 04:28:53  2013-12-04 06:16:19
#
# [5 rows x 58 columns]

# %%
combo.describe()
# Out:
#              index    salary_id  location_latitude  location_longitude  \
# count  2230.000000  2230.000000        1018.000000         1018.000000
# mean    826.791031  1684.661435          39.024273          -67.772112
# std     465.944009   908.735977          16.015822           64.513624
# min       0.000000     1.000000         -41.000000         -123.270000
# 25%     439.250000   957.250000          37.450000         -105.222500
# 50%     840.500000  1735.000000          38.870000          -95.000000
# 75%    1207.750000  2420.250000          47.610000          -71.060000
# max    1654.000000  3298.000000          65.000000          174.000000
#
#        total_experience_years  employer_experience_years  annual_base_pay  \
# count             2172.000000                2174.000000     2.224000e+03
# mean                 6.768490                   2.713257     4.727631e+06
# std                  5.644199                   3.721804     2.120712e+08
# min                  0.000000                   0.000000     0.000000e+00
# 25%                  3.000000                   1.000000     6.793750e+04
# 50%                  5.000000                   2.000000     1.030000e+05
# 75%                 10.000000                   3.000000     1.350000e+05
# max                 56.000000                  58.000000     1.000000e+10
#
#        signing_bonus  annual_bonus      entity_id   logo_width  logo_height  \
# count   1.809000e+03  1.818000e+03    1553.000000  1553.000000  1553.000000
# mean    2.031585e+04  1.297152e+04   55168.435930   322.412106   164.576304
# std     2.668673e+05  6.305806e+04   79882.567858   509.661668   313.928470
# min     0.000000e+00  0.000000e+00       3.000000     0.000000     0.000000
# 25%     0.000000e+00  0.000000e+00    1727.000000     0.000000     0.000000
# 50%     0.000000e+00  2.000000e+03   23825.000000   180.000000    68.000000
# 75%     7.000000e+03  1.450000e+04   56992.000000   397.000000   250.000000
# max     8.999999e+06  2.000000e+06  285989.000000  6097.000000  3872.000000
#
#        investment_rounds  invested_companies  funding_rounds  \
# count        1553.000000         1553.000000     1553.000000
# mean            9.039279            7.153896        0.935608
# std            49.348504           36.040482        2.155005
# min             0.000000            0.000000        0.000000
# 25%             0.000000            0.000000        0.000000
# 50%             0.000000            0.000000        0.000000
# 75%             2.000000            2.000000        1.000000
# max           529.000000          383.000000       13.000000
#
#        funding_total_usd   milestones  relationships
# count       1.553000e+03  1553.000000    1553.000000
# mean        7.509187e+07     2.069543     155.265937
# std         3.458668e+08     1.753584     324.950094
# min         0.000000e+00     0.000000       0.000000
# 25%         0.000000e+00     0.000000       0.000000
# 50%         0.000000e+00     2.000000       5.000000
# 75%         2.500000e+06     3.000000     100.000000
# max         2.425700e+09     8.000000    1189.000000

# %%
print(combo['invested_companies'].isnull().sum())
# Out:
# 677
